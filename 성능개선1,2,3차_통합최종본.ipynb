# %% [markdown]
# <a href="https://colab.research.google.com/github/mminn94/Machine-Learning/blob/chaemin-dev/%EC%84%B1%EB%8A%A5%EA%B0%9C%EC%84%A01%2C2%2C3%EC%B0%A8_%ED%86%B5%ED%95%A9%EC%B5%9C%EC%A2%85%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **현재 딱히 필요없는 것들(굳이 수행X) - 지웠어요**
# 1. 이미지 EDA 관련 코드 (분포 확인, 크기 확인, 샘플 이미지)
# 2. **MobileNetV2 초기모델** -> 할 필요 없어요. 어차피 뒤에 비교 실험 후 최종 모델 할 때 다시 불러와서 하게 되니까
# 3. 시각화에 대한 모든 것들
# 4. 비교 실험
# -> 결론인 H256, Dropout 0.5만 수행해도 됨
# 5. output 성능 지표들 (하윤 담당한 거)

# %% [markdown]
# **코드 수정한 것들**
#
# 적용 안한 _0들끼리 사실상 같은 거임
# => _1 (적용한 것들만 함수 만들어서 껐다 켰다 하면 됨)

# %% [markdown]
# # 데이터 처리 - 나영

# %%
## 저번에 와르르 실행시키는 셀을 아래쪽에 만들었었는데
## 그게 더 번거로운 거 같아서 그냥 각 셀마다 넣어놨습니다!!
## 위에서부터 차례로 하나씩 하면 됩니다

##맨 처음에 꼭 content 폴더에 kaggle.json을 옮겨놔주세요. (원래 있는 sample_data폴더랑 형제가 되도록))

## 주요 수정 사항 ##
# 압축 해제한거를 굳이 새로 카피할 필요가 없어져서 르네상스_식민주의 폴더만 '르네상스'로 이름 변경 & 하위폴더에 식민주의 관련 파일들 삭제만 함
# 클래스별 500개씩 , 128*128 사이즈 (MobileNetV2 표준)

# %%
#설치 모음
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import callbacks, layers, models, optimizers
import numpy as np
import random
import math
import pathlib
import os # 'os' 라이브러리: 파일 경로를 다루거나, 디렉토리를 만들고, 파일 목록을 읽는 등 운영체제와 관련된 기능을 제공
from pathlib import Path

import shutil   # 'shutil' 라이브러리: 파일 복사, 이동, 삭제 등 파일 작업 도움
import itertools
import glob
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

from sklearn.metrics import (accuracy_score, f1_score, confusion_matrix,
                             classification_report, precision_recall_fscore_support)

import matplotlib.pyplot as plt # 데이터를 그래프로 시각화
import matplotlib.ticker as ticker
import matplotlib.image as mpimg
import pandas as pd # 데이터를 표(테이블) 형태로
from PIL import Image
from matplotlib.ticker import MaxNLocator

# %%
root_path = Path('/content')
dataset_path = Path(root_path/'dataset') #데이터셋 폴더 경로
print(dataset_path)
# Out:
# /content/dataset

# %%
###리셋용 : 아마 쓸일 없을 텐데 쓴다면 필요한 부분만 주석 취소하고..
def reset():
  # shutil.rmtree("/content/dataset")
  # !rm -rf /content/
  # !rm -rf /content/dataset/
  # !rm -rf /content/Capstone_Architectural_Styles_dataset/
  # !rm -rf /content/data/architectural-styles-periods-dataset.zip

  # print("기존 폴더 삭제 완료.")

# reset()

# %%
### 캐글 api설치 ~ 데이터셋 다운,압축해제,압축파일삭제 ~ 폴더명변경
def InitialSettings():
  # !pip install kaggle #kaggle 라이브러리 설치
  # !mkdir -p ~/.kaggle #kaggle 폴더 생성
  if os.path.exists('kaggle.json'):
    # !cp kaggle.json ~/.kaggle/ #폴더에 kaggle.json 파일 복사
    # !chmod 600 ~/.kaggle/kaggle.json #kaggle.json 파일 권한 설정

    if os.path.exists('/root/.kaggle/kaggle.json'):
        # !kaggle datasets download -d gustavoachavez/architectural-styles-periods-dataset -p {root_path}  #데이터셋 다운로드
        # !unzip {root_path}/architectural-styles-periods-dataset.zip -d {root_path}  #데이터셋 압축 해제

        # !rm -rf {root_path}/sample_data #원래 있는 샘플데이터 폴더 삭제
        # !rm -rf {root_path}/architectural-styles-periods-dataset.zip #압축zip파일 삭제

        if os.path.exists(f'{root_path}/Capstone_Architectural_Styles_dataset'):
            # !mv {root_path}/Capstone_Architectural_Styles_dataset {root_path}/dataset #파일명 dataset으로 변경
        else:
            print("Capstone_Architectural_Styles_dataset 폴더 없음")
    else:
        print("Kaggle API key file 없음 /root/.kaggle/kaggle.json.")
  else:
      print("kaggle.json 없음. 파일 업로드 했는지 확인.")

###실행
InitialSettings()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5320.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53200.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53201.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53202.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53203.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53204.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53205.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53206.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53207.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53208.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53209.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5321.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53210.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53211.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53212.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53213.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53214.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53215.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53216.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53217.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53218.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53219.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5322.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53220.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53221.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53222.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53223.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53224.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53225.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53226.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53227.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53228.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53229.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5323.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53230.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53231.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53232.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53233.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53234.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53235.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53236.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53237.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53238.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53239.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5324.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53240.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53241.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53242.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53243.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53244.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53245.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53246.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53247.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53248.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53249.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5325.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53250.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53251.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53252.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53253.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53254.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53255.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53256.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53257.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53258.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53259.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5326.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53260.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53261.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/53262.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5327.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5328.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5329.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/533.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5330.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5331.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5332.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5333.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5334.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5335.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5336.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5337.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5338.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5339.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/534.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5340.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5341.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5342.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5343.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5344.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5345.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5346.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5347.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5348.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5349.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/535.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5350.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5351.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5352.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5353.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5354.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5355.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5356.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5357.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5358.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5359.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/536.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5360.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5361.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5362.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5363.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5364.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5365.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5366.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5367.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5368.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5369.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/537.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5370.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5371.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5372.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5373.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5374.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5375.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5376.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5377.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5378.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5379.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/538.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5380.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5381.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5382.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5383.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5384.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5385.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5386.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5387.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5388.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5389.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/539.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5390.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5391.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5392.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5393.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5394.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5395.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5396.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5397.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5398.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/Chicago school architecture/5399.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/540.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/541.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5410.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54100.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54101.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54102.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54103.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54104.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54105.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54106.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54107.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54108.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54109.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5411.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54110.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54111.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54112.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54113.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54114.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54115.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54116.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54117.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54118.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54119.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5412.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54120.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54121.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54122.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54123.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54124.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54125.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54126.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54127.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54128.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54129.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5413.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54130.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54131.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54132.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54133.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54134.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54135.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54136.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54137.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54138.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54139.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5414.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54140.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54141.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54142.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54143.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54144.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54145.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54146.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54147.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54148.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54149.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5415.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54150.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54151.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54152.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54153.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54154.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54155.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54156.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54157.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54158.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54159.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5416.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54160.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54161.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54162.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54163.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54164.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54165.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54166.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54167.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54168.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54169.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5417.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54170.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54171.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54172.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54173.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54174.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54175.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54176.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54177.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54178.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54179.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5418.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54180.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54181.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54182.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54183.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54184.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54185.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54186.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54187.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54188.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54189.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5419.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54190.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54191.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54192.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54193.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54194.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54195.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54196.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54197.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54198.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54199.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/542.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5420.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54200.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54201.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54202.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54203.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54204.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54205.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54206.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54207.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54208.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54209.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5421.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54210.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54211.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54212.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54213.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54214.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54215.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54216.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54217.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54218.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54219.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5422.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54220.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54221.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54222.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54223.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54224.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54225.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54226.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54227.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54228.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54229.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5423.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54230.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54231.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54232.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54233.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54234.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54235.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54236.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54237.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54238.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54239.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5424.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54240.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54241.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54242.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54243.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54244.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54245.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54246.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54247.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54248.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54249.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5425.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54250.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54251.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54252.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54253.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54254.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54255.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54256.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54257.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54258.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54259.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5426.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54260.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54261.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54262.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54263.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54264.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54265.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54266.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54267.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54268.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54269.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5427.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54270.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54271.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54272.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54273.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54274.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54275.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54276.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54277.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54278.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54279.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5428.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54280.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54281.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54282.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54283.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54284.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54285.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54286.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54287.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54288.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54289.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5429.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54290.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54291.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54292.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54293.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54294.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54295.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54296.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54297.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54298.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54299.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/543.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5430.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54300.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54301.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54302.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54303.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54304.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54305.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54306.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54307.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54308.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54309.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5431.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54310.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54311.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54312.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54313.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54314.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54315.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54316.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54317.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54318.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54319.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5432.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54320.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54321.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54322.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54323.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54324.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54325.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54326.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54327.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54328.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54329.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5433.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54330.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54331.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54332.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54333.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54334.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54335.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54336.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54337.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54338.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54339.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5434.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54340.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54341.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54342.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54343.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54344.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54345.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54346.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54347.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54348.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54349.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5435.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54350.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54351.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54352.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54353.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54354.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54355.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54356.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54357.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54358.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54359.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5436.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54360.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54361.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54362.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54363.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54364.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54365.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54366.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54367.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54368.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54369.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/5437.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54370.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54371.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54372.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54373.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54374.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54375.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Modernism/International style/54376.jpg
# ...
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85361.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85362.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85363.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85364.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85365.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85366.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85367.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85368.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85369.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8537.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85370.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85371.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85372.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85373.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85374.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85375.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85376.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85377.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85378.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85379.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8538.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85380.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85381.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85382.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85383.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85384.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85385.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85386.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85387.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85388.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85389.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8539.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85390.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85391.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85392.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85393.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85394.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85395.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85396.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85397.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85398.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85399.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/854.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8540.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85400.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85401.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85402.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85403.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85404.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85405.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85406.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85407.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85408.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85409.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8541.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85410.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85411.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85412.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85413.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85414.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85415.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85416.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85417.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85418.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85419.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8542.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85420.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85421.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85422.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85423.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85424.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85425.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85426.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85427.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85428.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85429.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8543.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85430.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85431.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85432.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85433.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85434.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85435.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85436.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/85437.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8544.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8545.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8546.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8547.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8548.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8549.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/855.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8550.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8551.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8552.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8553.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8554.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8555.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8556.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8557.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8558.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8559.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/856.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8560.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8561.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8562.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8563.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8564.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8565.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8566.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8567.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8568.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8569.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/857.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8570.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8571.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8572.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8573.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8574.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8575.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8576.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8577.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8578.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8579.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/858.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8580.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8581.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8582.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8583.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8584.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8585.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8586.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8587.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8588.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8589.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/859.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8590.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8591.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8592.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8593.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8594.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8595.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8596.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8597.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8598.jpg
#   inflating: /content/Capstone_Architectural_Styles_dataset/Revivalism/Tudor Revival architecture/8599.jpg

# %% [markdown]
# 식민주의 삭제 시 오류 수정 - 나영 251110

# %%
## dataset 하위 디렉터리에서 식민주의 Colonialism 삭제 :
# 1) 이름변경 : Renaissance_and어쩌구 => Renaissance
# 2) 그 폴더 안에 식민주의 관련 파일 폴더 다 삭제 ('Colonial' or 'Georgian' 포함된 파일명)

def deleteColonialism(dataset_path: Path):
  # Check if the dataset directory exists before proceeding
  if not dataset_path.exists():
      print(f"Dataset 폴더 없음- {dataset_path}.")
      return

  new_class_path = None # # 변경된 폴더의 경로 (이름이 'Renaissance'로 바뀐 후의 경로)를 저장할 변수

  for class_path in dataset_path.iterdir():
    # print(class_path.name)
    if 'Renaissance' in class_path.name and class_path.is_dir() :
      if class_path.name != 'Renaissance': # 이름이 변경 전일 경우
        new_class_path = class_path.parent / 'Renaissance' # 변경된 폴더의 경로 (이름이 'Renaissance'로 바뀐 후의 경로)
        # !mv {class_path} {new_class_path} #1) 폴더명 변경
        class_path = new_class_path # class_path를 변경된 폴더의 경로로 업데이트
      else : # 이미 이름이 'Renaissance'인 경우, 새 경로 변수를 현재 경로로 설정
        new_class_path = class_path

      for Rene_child_path in class_path.iterdir():
        if (Rene_child_path.is_dir()) and ('Colonial' in Rene_child_path.name )or ('Georgian' in Rene_child_path.name):
          shutil.rmtree(Rene_child_path) #2) 폴더 안에 식민주의 관련 파일 폴더 다 삭제
  # print("--- 현재 폴더 구조 ---")
  # !find {dataset_path}/ -maxdepth 2 -type d -print


deleteColonialism(dataset_path)

# %%
# 각 클래스 디렉토리의 하위 폴더 통합
def mergeChildDir():
  for class_path in dataset_path.iterdir(): #클래스 폴더 순회
    # print(class_path)
    for child_path in list(class_path.iterdir()): #하위 폴더 순회. list감싸서 나중에 변경 안 되도록
      if child_path.is_dir():
        # print(child_path)
        for img_file in child_path.iterdir(): #이미지 파일 순회
          destination_path = class_path/img_file.name #파일별 최종 경로 (클래스폴더/이미지파일.jpg)
          # print(destination_path)
          if destination_path.exists():
            print(f"!!!!!! Warning: '{destination_path.name}' 이미 있음.")
            continue # 건너뛰기
          shutil.move(str(img_file), str(destination_path)) # 파일 이동

        os.rmdir(child_path)


###실행
mergeChildDir();

# %%
# 폴더별 이미지 개수 확인 - 딕셔너리 형태 반환
def countImgsPerClass():
  class_img_counts = {}
  total_count = 0

  for class_dir in dataset_path.iterdir():
    # print(class_dir.name)

    if class_dir.is_dir(): #isdir : '파일'이 아니라 '폴더'가 맞는지 확인
      # print(class_dir.name)
      count = len(list(class_dir.iterdir()))
      # print(count)
      class_img_counts[class_dir.name]=count
      total_count+=count

  # print("총 이미지 개수:",total_count)
  # print("클래스별 이미지 개수:",class_img_counts)
  return class_img_counts

###실행
countImgsPerClass()
# Out:
# {'Renaissance': 521,
#  'Modernism': 1860,
#  'Baroque': 1089,
#  'Eclecticism': 1315,
#  'Neoclassicism': 1225,
#  'Early_Christian_Medieval': 1338,
#  'Classical': 1022,
#  '21st_Century': 1229,
#  'Revivalism': 1919}

# %% [markdown]
# # 이미지 수정사항 - 채민 251106 13:00
# 정규화할 때 알 수 없는 파일이 나타남 -> 미리 이상한 파일들 삭제 후 이미지 수 균일하게 줄이기

# %%
problematic_files = []
DATA_DIR = str(dataset_path)

# 허용할 유효한 이미지 확장자 목록
valid_extensions = ['.jpeg', '.jpg', '.png', '.bmp', '.gif']

print(f"'{DATA_DIR}'에서 유효하지 않은 확장자나 숨겨진 파일을 찾습니다...")

for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        file_path = os.path.join(root, file)

        # 1. 숨겨진 파일(이름이 '.'으로 시작)을 찾기 (예: .DS_Store)
        if file.startswith('.'):
            print(f"---[숨겨진 파일 발견]---: {file_path}")
            problematic_files.append(file_path)
            continue

        # 2. 확장자가 유효한 목록에 없는 파일을 찾기
        ext = os.path.splitext(file)[1].lower()
        if ext not in valid_extensions:
            print(f"---[유효하지 않은 확장자 발견]---: {file_path}")
            problematic_files.append(file_path)

# 3. 발견된 모든 문제 파일 삭제
if problematic_files:
    print(f"\n총 {len(problematic_files)}개의 문제 파일을 삭제합니다...")
    for file_path in problematic_files:
        os.remove(file_path)
    print("삭제 완료.")
else:
    print("확장자가 이상하거나 숨겨진 파일은 없습니다.")
# Out:
# '/content/dataset'에서 유효하지 않은 확장자나 숨겨진 파일을 찾습니다...
# 확장자가 이상하거나 숨겨진 파일은 없습니다.

# %%
# 1. 데이터셋 최상위 경로 (이전과 동일하게 설정)
DATA_DIR = str(dataset_path)

print(f"'{DATA_DIR}'에서 TensorFlow가 읽을 수 없는 파일을 정밀 검사합니다...")
problematic_files = []

# 2. 모든 파일 경로 수집
all_fnames = []
for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        all_fnames.append(os.path.join(root, file))

print(f"총 {len(all_fnames)}개의 파일을 검사합니다...")

# 3. TensorFlow 함수로 파일 검사
for file_path in all_fnames:
    try:
        # 1. TensorFlow가 파일을 읽는 방식
        img_bytes = tf.io.read_file(file_path)
        # 2. TensorFlow가 이미지를 디코딩하는 방식
        img = tf.io.decode_image(img_bytes)

    except Exception as e:
        # 3. 여기서 오류가 나면 model.fit()에서도 오류 발생
        print(f"---[문제 파일 발견]---: {file_path}")
        print(f"오류: {e}\n")
        problematic_files.append(file_path)

# 4. 발견된 모든 문제 파일 삭제
if problematic_files:
    print(f"\n총 {len(problematic_files)}개의 문제 파일을 삭제합니다...")
    for file_path in problematic_files:
        os.remove(file_path)
    print("삭제 완료.")
else:
    print("TensorFlow 기준으로도 문제가 되는 파일이 없습니다.")
# Out:
# '/content/dataset'에서 TensorFlow가 읽을 수 없는 파일을 정밀 검사합니다...
# 총 11518개의 파일을 검사합니다...
# ---[문제 파일 발견]---: /content/dataset/Renaissance/7186.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Renaissance/7464.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Renaissance/7641.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Renaissance/7197.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Renaissance/73115.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Renaissance/7462.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Modernism/52224.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Modernism/52167.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Modernism/52130.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Modernism/52281.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Modernism/52314.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Modernism/5240.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Baroque/1443.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Baroque/14156.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Baroque/1294.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Baroque/1441.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Baroque/1320.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Baroque/1427.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/3353.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/3258.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/33157.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/3232.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/33156.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/3284.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/331.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/321.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/3218.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/32118.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/32112.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/3371.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Early_Christian_Medieval/3344.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2248.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2358.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2382.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2296.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/23105.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2316.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2330.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2293.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2250.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/22134.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2391.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/Classical/2350.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/21st_Century/0285.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/21st_Century/00182.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/21st_Century/00196.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/21st_Century/03116.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
# ---[문제 파일 발견]---: /content/dataset/21st_Century/00129.jpg
# 오류: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
#
#
# 총 48개의 문제 파일을 삭제합니다...
# 삭제 완료.

# %% [markdown]
# 500장 이하로 줄어들 수도 있기 때문에 확인 절차

# %%
# 폴더별 이미지 개수 확인 - 딕셔너리 형태 반환

countImgsPerClass()
# Out:
# {'Renaissance': 515,
#  'Modernism': 1854,
#  'Baroque': 1083,
#  'Eclecticism': 1315,
#  'Neoclassicism': 1225,
#  'Early_Christian_Medieval': 1325,
#  'Classical': 1010,
#  '21st_Century': 1224,
#  'Revivalism': 1919}

# %%
## 이미지 수 균일하게 줄이기.
def reductionFiles(numPerClass=500):
  class_img_counts = countImgsPerClass()
  min_img_counts=min(class_img_counts.values())
  print("파일 삭제 전 : ",class_img_counts)

  if min_img_counts<numPerClass:
    print(f"{numPerClass}보다 적은 클래스가 존재합니다.")
    return
  else:
    for class_dir in dataset_path.iterdir():
      class_all_imgs=[f for f in class_dir.iterdir()
                         if f.is_file() and not f.name.startswith('.')]

      class_all_imgs.sort() # 또는 class_all_imgs = sorted(class_all_imgs)
      # random.shuffle(class_all_imgs)


      files_to_delete = class_all_imgs[numPerClass:]#삭제할 파일(500개 초과분)만 선택
      for img_file in files_to_delete:
        img_file.unlink()
  print("파일 삭제 완료")
  return countImgsPerClass()

###실행
reductionFiles()
# Out:
# 파일 삭제 전 :  {'Renaissance': 515, 'Modernism': 1854, 'Baroque': 1083, 'Eclecticism': 1315, 'Neoclassicism': 1225, 'Early_Christian_Medieval': 1325, 'Classical': 1010, '21st_Century': 1224, 'Revivalism': 1919}
# 파일 삭제 완료
# {'Renaissance': 500,
#  'Modernism': 500,
#  'Baroque': 500,
#  'Eclecticism': 500,
#  'Neoclassicism': 500,
#  'Early_Christian_Medieval': 500,
#  'Classical': 500,
#  '21st_Century': 500,
#  'Revivalism': 500}

# %%
# ----------------------------------------------------------------
# 1. 기본 설정
# ----------------------------------------------------------------
DATA_DIR = pathlib.Path(str(dataset_path))
IMG_SIZE_INT = 128
BATCH_SIZE = 32
SEED = 42
AUTOTUNE = tf.data.AUTOTUNE

print("데이터셋 수동 파이프라인 구축 시작...")

# ----------------------------------------------------------------
# 2. 파일 리스트 및 클래스 정의
# ----------------------------------------------------------------
all_image_paths = list(DATA_DIR.glob('*/*'))
all_image_paths = [str(path) for path in all_image_paths]

# 클래스 이름 추출 및 정렬
class_names = sorted([item.name for item in DATA_DIR.glob('*') if item.is_dir()])
num_classes = len(class_names)

print(f"--- 총 이미지 개수: {len(all_image_paths)} ---")
print(f"--- 클래스 목록 ({num_classes}개): {class_names} ---")

# 랜덤 셔플
random.seed(SEED)
random.shuffle(all_image_paths)

# Train / Validation 분리
val_count = int(len(all_image_paths) * 0.2)
train_paths = all_image_paths[val_count:]
val_paths = all_image_paths[:val_count]

print(f"--- 훈련 데이터: {len(train_paths)}장 / 검증 데이터: {len(val_paths)}장 ---")

# ----------------------------------------------------------------
# 3. 데이터 로드 함수 (핵심 수정됨!)
# ----------------------------------------------------------------

# 클래스 이름들을 미리 Tensor 상수로 변환해둡니다. (함수 내부에서 쓰기 위함)
class_names_tensor = tf.constant(class_names)

def load_image_and_label(path):
    # 1) 이미지 읽기
    image = tf.io.read_file(path)
    image = tf.io.decode_image(image, channels=3, expand_animations=False)
    image.set_shape([None, None, 3]) # 모양 힌트 제공

    # 2) 라벨 추출
    parts = tf.strings.split(path, os.path.sep)
    label_name = parts[-2]

    # 3) [수정된 부분] for문 제거 -> TensorFlow 비교 연산 사용
    # 전체 클래스 이름 리스트와 현재 라벨 이름을 한 번에 비교합니다.
    # 예: label_name='Baroque', class_names=['21st', 'Baroque', ...]
    # comparison -> [False, True, False, ...]
    comparison = tf.equal(class_names_tensor, label_name)

    # True가 있는 위치(인덱스)를 찾습니다.
    label_index = tf.argmax(comparison)

    # 원-핫 인코딩
    label = tf.one_hot(label_index, depth=num_classes)

    return image, label

# tf.data.Dataset 생성
train_ds_raw = tf.data.Dataset.from_tensor_slices(train_paths)
train_ds_raw = train_ds_raw.map(load_image_and_label, num_parallel_calls=AUTOTUNE)

val_ds_raw = tf.data.Dataset.from_tensor_slices(val_paths)
val_ds_raw = val_ds_raw.map(load_image_and_label, num_parallel_calls=AUTOTUNE)

# ----------------------------------------------------------------
# 4. 전처리 함수
# ----------------------------------------------------------------
def preprocess_squash(image, label):
    image = tf.image.resize(image, (IMG_SIZE_INT, IMG_SIZE_INT))
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

# ----------------------------------------------------------------
# 5. 파이프라인 분기 (데이터셋 2세트 생성)
# ----------------------------------------------------------------

train_ds_A0 = train_ds_raw.map(preprocess_squash, num_parallel_calls=AUTOTUNE)
val_ds_A0   = val_ds_raw.map(preprocess_squash, num_parallel_calls=AUTOTUNE)

train_ds_A0 = train_ds_A0.batch(BATCH_SIZE).cache().prefetch(AUTOTUNE)
val_ds_A0   = val_ds_A0.batch(BATCH_SIZE).cache().prefetch(AUTOTUNE)

print("모든 데이터셋 준비 완료!")
# Out:
# 데이터셋 수동 파이프라인 구축 시작...
# --- 총 이미지 개수: 4500 ---
# --- 클래스 목록 (9개): ['21st_Century', 'Baroque', 'Classical', 'Early_Christian_Medieval', 'Eclecticism', 'Modernism', 'Neoclassicism', 'Renaissance', 'Revivalism'] ---
# --- 훈련 데이터: 3600장 / 검증 데이터: 900장 ---
# 모든 데이터셋 준비 완료!

# %% [markdown]
# # 이미지 수정사항 - 채민 251106 13:00
# MobileNetV2에서는 128 * 128 이미지가 표준이어서 이미지 크기 변경

# %%
DATA_DIR = str(dataset_path) #/content/data/Merged_dataset
# print(DATA_DIR)
# 이미지 사이즈/배치/seed
IMG_SIZE = (128, 128)
BATCH_SIZE = 32
SEED = 42 #데이터를 나눌 때 사용할 랜덤 시드
AUTOTUNE = tf.data.AUTOTUNE #tf.data 파이프라인의 성능을 자동으로 최적화

#데이터셋 파이프라인 구축 (Train/Val 분리)
# def createTrainValDatasets():
train_ds_A0 = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,             # 6개 클래스 폴더가 들어있는 상위 폴더
    labels="inferred",    # 폴더명을 라벨로 사용
    label_mode="categorical",      # 원-핫 인코딩 (다중 클래스 분류용)
    validation_split=0.2, # 전체 데이터 중 20%를 검증용으로 validation
    subset="training",    # "나머지 80% -> 훈련용 데이터 training
    seed=SEED,
    image_size=IMG_SIZE,  # 모든 이미지를 자동 리사이징
    batch_size=BATCH_SIZE
)
val_ds_A0 = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",    # 폴더명을 라벨로 사용
    label_mode="categorical",      # 원-핫 인코딩 (다중 클래스 분류용)
    validation_split=0.2, # 전체 데이터 중 20%를 검증용으로 validation
    subset="validation",    # "나머지 80% -> 훈련용 데이터 training
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Keras가 폴더명을 기반으로 자동 생성한 클래스 이름들을 확인.
# (0번 = '21st_Century', 1번 = 'Baroque_Rococo', ... 알파벳 순서로 자동 정렬)
class_names = train_ds_A0.class_names
print("\n--- 클래스 이름 (자동 생성된 라벨 순서) ---")
print(class_names)
# 파이프라인 최적화(캐시/프리패치)
# - 캐시: 반복(epoch) 시 디스크 재읽기 최소화(메모리에 여유가 있으면 좋음)
# - 프리패치: 다음 배치를 미리 준비하여 GPU/CPU 대기시간 단축
train_dataset = train_ds_A0.cache().prefetch(AUTOTUNE)
val_dataset   = val_ds_A0.cache().prefetch(AUTOTUNE)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.
#
# --- 클래스 이름 (자동 생성된 라벨 순서) ---
# ['21st_Century', 'Baroque', 'Classical', 'Early_Christian_Medieval', 'Eclecticism', 'Modernism', 'Neoclassicism', 'Renaissance', 'Revivalism']

# %% [markdown]
# # 정규화 수정사항 - 채민 251106 01:30
# 현재 MobileNetV2 모델은 ImageNet으로 사전 훈련할 때 -1 ~ +1 범위로 정규화된 이미지를 사용
# -> Rescaling(1./255) 대신 preprocess_input 함수 (MobileNetV2 전용함수)를 사용해야함

# %%
# 정규화·증강 레이어 파이프라인에 적용

# def realReadyDataSets():
# train_dataset, val_dataset, class_names=createTrainValDatasets()
###데이터 증강(Augmentation)
# [수정사항 - 채민] 0~255 픽셀을 -1~+1 범위로 정규화 (MobileNetV2 전용 함수)
# rescale = layers.Rescaling(1./255)
#데이터 증강(Augmentation) 레이어 정의 (학습 데이터에만 적용)
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

data_augmentation = keras.Sequential(   # 'Sequential' 모델을 사용해 증강 기법들을 파이프라인처럼 만든다.
    [                                   # 훈련 중에 실시간으로 이미지를 변형
        layers.RandomFlip("horizontal"),   # 좌우 뒤집기
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),            # 10% 줌 인/아웃
        layers.RandomContrast(0.1),        # 대비 변화
    ],
    name="data_augmentation"# 이름 붙이기
)
## training학습용 : 증강(data_augmentation) -> MobileNetV2 정규화만 적용
train_dataset_ready = (
    train_dataset
    .map(lambda x, y: (preprocess_input(data_augmentation(x)),y), num_parallel_calls=AUTOTUNE) #x:원본이미지, y:원본레이블
    .prefetch(AUTOTUNE)
)
## 검증용 :MobileNetV2 정규화만!
val_dataset_ready = (
    val_dataset
    .map( lambda x, y: (preprocess_input(x),y), num_parallel_calls=AUTOTUNE)
    .prefetch(AUTOTUNE)
)
print("[OK] 파이프라인 (MobileNetV2 정규화 적용) 준비 완료.")
# return train_dataset_ready, val_dataset_ready, class_names

# 한 배치 꺼내서 모양 확인
print("한 배치 꺼내서 모양 확인")
xb, yb = next(iter(train_dataset_ready))
print("이미지 배치:", xb.shape, xb.dtype)
# 이미지 배치:            예 : (32, 224, 224, 3) <dtype: 'float32'>
# 이미지 배치 (입력 데이터): (배치 크기, 세로px, 가로px, 채널수:rgb) <dtype: 'float32'>
# 의미 : 32장의 224×224 RGB 컬러 이미지

print("라벨 배치 :", yb.shape, yb.dtype)
# 라벨 배치 :            (32, 6) <dtype: 'float32'>
# 라벨 배치 (정답 데이터) : (배치크기, 클래스 수) <dtype: 'float32'>
# 의미 : 9개 클래스 중 해당되는 위치가 1인 one-hot 벡터 ex[0., 0., 0., 0., 1., 0.]

print("정규화 후 최소값: ", tf.reduce_min(xb).numpy())
print("정규화 후 최대값: ", tf.reduce_max(xb).numpy())
# Out:
# [OK] 파이프라인 (MobileNetV2 정규화 적용) 준비 완료.
# 한 배치 꺼내서 모양 확인
# 이미지 배치: (32, 128, 128, 3) <dtype: 'float32'>
# 라벨 배치 : (32, 9) <dtype: 'float32'>
# 정규화 후 최소값:  -1.0
# 정규화 후 최대값:  1.0

# %%
def show_augment_comparison(train_dataset,
                            data_augmentation,
                            class_names=None,
                            max_images=8):
    """
    train_dataset에서 배치 1개를 꺼내 '증강 전/후' 이미지를 8장 비교로 보여줍니다.
    - 위 줄: 증강 전(원본 배치에서 꺼낸 이미지)
    - 아래 줄: 같은 이미지에 data_augmentation을 적용한 결과
    """
    # 배치 하나 추출
    images, labels = next(iter(train_dataset))
    n = min(max_images, images.shape[0])
    images = images[:n]  # (n, H, W, 3)

    # labels가 one-hot이면 argmax로 인덱스 변환
    try:
        label_idx = tf.argmax(labels[:n], axis=1).numpy()
    except Exception:
        # sparse일 수도 있으니 대비
        label_idx = labels[:n].numpy().astype(int).reshape(-1)

    # ----- 증강 적용 (training=True를 명시해서 랜덤 변환 강제) -----
    # 주의: data_augmentation은 정규화 전/후 모두 동작하지만,
    # 보통은 정규화 전 uint8/float32 범위(0~255) 이미지에 적용해도 무방합니다.
    aug_images = data_augmentation(images, training=True)

    # ----- 시각화용 유틸: 값을 0~255로 맞춘 뒤 uint8로 캐스팅 -----
    def to_uint8(x):
        x = tf.convert_to_tensor(x, dtype=tf.float32)
        # 만약 0~1 범위라면 255 스케일, 0~255면 그대로 클리핑만
        mx = tf.reduce_max(x)
        x = tf.where(mx <= 1.0, x * 255.0, x)
        x = tf.clip_by_value(x, 0.0, 255.0)
        return tf.cast(x, tf.uint8).numpy()

    vis_orig = to_uint8(images)
    vis_aug  = to_uint8(aug_images)

    # ----- 플로팅 -----
    plt.figure(figsize=(2.2*n, 5))
    # 윗줄: 원본
    for i in range(n):
        plt.subplot(2, n, i+1)
        plt.imshow(vis_orig[i])
        title = None
        if class_names is not None:
            title = class_names[label_idx[i]]
        if title:
            plt.title(title, fontsize=10)
        plt.axis("off")
    # 아랫줄: 증강 후
    for i in range(n):
        plt.subplot(2, n, n + i + 1)
        plt.imshow(vis_aug[i])
        plt.axis("off")
    plt.suptitle("Before augmentation (top) \n After augmentation (bottom)", fontsize=13)
    plt.tight_layout()
    plt.show()
show_augment_comparison(train_dataset,data_augmentation,'Baroque_Rococo',4 )

# %% [markdown]
# # A1 (정사각형 + 증강)

# %%
#  A1용 데이터 증강  (정사각형 + 증강)
data_augmentation_A1 = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        layers.RandomTranslation(0.1, 0.1),
    ],
    name="aug_A1_square_plus_aug"
)

def preprocess_squash_with_aug(image, label):
    image = tf.image.resize(image, (IMG_SIZE_INT, IMG_SIZE_INT))
    image = tf.cast(image, tf.float32)

    image = data_augmentation_A1(image, training=True)

    return image, label

#  A1용 (정사각형 + 증강)
# train: 정사각형 + 증강
train_ds_A1 = train_ds_raw.map(
    preprocess_squash_with_aug,
    num_parallel_calls=AUTOTUNE
)
train_ds_A1 = train_ds_A1.batch(BATCH_SIZE).cache().prefetch(AUTOTUNE)

# val: 정사각형만 (A0와 동일, 증강 X)
val_ds_A1 = val_ds_raw.map(
    preprocess_squash,
    num_parallel_calls=AUTOTUNE
)
val_ds_A1 = val_ds_A1.batch(BATCH_SIZE).cache().prefetch(AUTOTUNE)

print("A0 / A1 데이터셋 준비 완료!")
# Out:
# A0 / A1 데이터셋 준비 완료!

# %% [markdown]
# # MobileNetV2 최종 H256, D0.5

# %%
## 1. 실험 준비
INPUT_SHAPE = (128, 128, 3)
NUM_CLASSES = 9

# 실험용 모델 생성 함수 (헤드 구조/Dropout 실험용)
def build_model_head(head_units=128, dropout_rate=0.5, lr=0.001, optimizer_name = "adam"):   # 입력 없을 때의 디폴트 값
    # 백본 MobileNetV2 다시 불러오기 (동일한 설정)
    base_model = tf.keras.applications.MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = False  # 앞부분과 동일하게 동결

    inputs = layers.Input(shape=INPUT_SHAPE)
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(head_units, activation='relu')(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

    model = models.Model(inputs, outputs)   # 입력 -> 출력 연결한 모델 완성

    # 모델 컴파일
    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
## 4. 최종 모델 결정 및 학습 (H256 and D0.5)
def run_final_training(train_ds, val_ds, mode_name="final_head"):
    """
    train_ds: 학습 데이터셋 (A0)
    val_ds  : 검증 데이터셋
    mode_name: 파일 저장명 (기본값: final_head)
    """

    # (1) 설정값 정의 (최종 결정된 값 H256, D0.5, LR 0.001)
    HEAD_UNITS = 256
    DROPOUT_RATE = 0.5
    LEARNING_RATE = 0.001
    EPOCHS = 10

    print(f"=== [{mode_name}] 최종 학습 시작 ===")
    print(f"설정: Units={HEAD_UNITS}, Drop={DROPOUT_RATE}, LR={LEARNING_RATE}")

    # (2) 폴더 생성
    os.makedirs("runs", exist_ok=True)

    # (3) 모델 생성
    model = build_model_head(HEAD_UNITS, DROPOUT_RATE, LEARNING_RATE)

    # (4) 콜백 설정 (파일 이름이 mode_name에 따라 결정됨)
    # 예: runs/best_head_final_A0.keras
    ckpt_path = f"runs/best_head_{mode_name}.keras"
    log_path = f"runs/train_log_{mode_name}.csv"

    cbs = [
        callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
        callbacks.ModelCheckpoint(ckpt_path, monitor='val_accuracy', mode='max', save_best_only=True),
        callbacks.CSVLogger(log_path)
    ]

    # (5) 학습 시작
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=cbs,
        verbose=1
    )

    print(f"--- [{mode_name}] 학습 완료! 저장경로: {ckpt_path} ---")
    return model, history

# %% [markdown]
# 모델 이름
#
# 최종 모델 = best_head_final_head.keras
#
# **증강 처리 X (A0) = best_head_A0_Squash** = 기본 비교 모델
#
# 증강 처리 모델(A1) = best_head_A1_Squash_Aug
#
# 옵티마이저 변화 (B1) = best_head_B1_AdamW
#
# 동결 해제 (C1) = best_head_C1_FineTuned

# %% [markdown]
# # A0, A1 데이터 증강 - 하윤

# %%
#  A0 vs A1
# A0: 정사각형(Squash) 데이터로 학습
model_A0, history_A0 = run_final_training(train_ds_A0, val_ds_A0, "A0_Squash")
# Out:
# === [A0_Squash] 최종 학습 시작 ===
# 설정: Units=256, Drop=0.5, LR=0.001
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 745ms/step - accuracy: 0.2273 - loss: 2.2954 - val_accuracy: 0.3389 - val_loss: 1.8531
# Epoch 2/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 83s 725ms/step - accuracy: 0.3354 - loss: 1.8279 - val_accuracy: 0.3500 - val_loss: 1.7888
# Epoch 3/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 84s 741ms/step - accuracy: 0.3691 - loss: 1.7360 - val_accuracy: 0.3778 - val_loss: 1.7118
# Epoch 4/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 106s 939ms/step - accuracy: 0.4008 - loss: 1.6706 - val_accuracy: 0.3967 - val_loss: 1.6853
# Epoch 5/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 102s 903ms/step - accuracy: 0.4180 - loss: 1.6223 - val_accuracy: 0.4089 - val_loss: 1.6639
# Epoch 6/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 80s 703ms/step - accuracy: 0.4345 - loss: 1.5840 - val_accuracy: 0.3978 - val_loss: 1.6576
# Epoch 7/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 78s 683ms/step - accuracy: 0.4303 - loss: 1.5476 - val_accuracy: 0.4200 - val_loss: 1.6195
# Epoch 8/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 87s 733ms/step - accuracy: 0.4650 - loss: 1.5027 - val_accuracy: 0.4322 - val_loss: 1.6308
# Epoch 9/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 722ms/step - accuracy: 0.4439 - loss: 1.4923 - val_accuracy: 0.4267 - val_loss: 1.6252
# Epoch 10/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 77s 673ms/step - accuracy: 0.4699 - loss: 1.4843 - val_accuracy: 0.4344 - val_loss: 1.6136
# --- [A0_Squash] 학습 완료! 저장경로: runs/best_head_A0_Squash.keras ---

# %%
# A1: 정사각형 + 증강 데이터로 학습
model_A1, history_A1 = run_final_training(train_ds_A1, val_ds_A1, "A1_Squash_Aug")

print("최종 모델 (A0: Squash / A1: Squash+Aug) 2개 학습 완료!")
# Out:
# === [A1_Squash_Aug] 최종 학습 시작 ===
# 설정: Units=256, Drop=0.5, LR=0.001
# Epoch 1/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 70s 541ms/step - accuracy: 0.1900 - loss: 2.3974 - val_accuracy: 0.1222 - val_loss: 2.4453
# Epoch 2/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 78s 506ms/step - accuracy: 0.2569 - loss: 1.9743 - val_accuracy: 0.1078 - val_loss: 2.8083
# Epoch 3/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 68s 601ms/step - accuracy: 0.2801 - loss: 1.9030 - val_accuracy: 0.1178 - val_loss: 3.1377
# Epoch 4/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 90s 673ms/step - accuracy: 0.2969 - loss: 1.8796 - val_accuracy: 0.1156 - val_loss: 3.2935
# Epoch 5/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 59s 522ms/step - accuracy: 0.3191 - loss: 1.8365 - val_accuracy: 0.1167 - val_loss: 3.6528
# Epoch 6/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 81s 517ms/step - accuracy: 0.3141 - loss: 1.8182 - val_accuracy: 0.1100 - val_loss: 3.8242
# --- [A1_Squash_Aug] 학습 완료! 저장경로: runs/best_head_A1_Squash_Aug.keras ---
# 최종 모델 (A0: Squash / A1: Squash+Aug) 2개 학습 완료!

# %%
# A0 (Squash) vs A1 (Squash + Aug) 검증 정확도 비교
acc_A0 = history_A0.history['val_accuracy']
acc_A1 = history_A1.history['val_accuracy']

plt.figure(figsize=(10, 6))

plt.plot(acc_A0, label='A0: Squash (Baseline)', linestyle='--', color='red')

plt.plot(acc_A1, label='A1: Squash + Aug', linewidth=2, color='green')

plt.title('Final Comparison: A0 (Squash) vs A1 (Squash + Aug) (Val Accuracy)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

best_A0 = max(acc_A0)
best_A1 = max(acc_A1)

print(f"[결과]")
print(f" - A0 (Squash) 최고 점수: {best_A0*100:.2f}%")
print(f" - A1 (Squash + Aug) 최고 점수: {best_A1*100:.2f}%")

if best_A1 > best_A0:
    print("A1 (Squash + Aug) 방식 추천 (데이터 증강 효과 확인)")
elif best_A0 > best_A1:
    print("A0 (Squash) 방식 추천 (증강이 성능을 떨어뜨림)")
else:
    print("결론: 두 방식의 성능 차이가 미미함.")
# Out:
# [결과]
#  - A0 (Squash) 최고 점수: 43.44%
#  - A1 (Squash + Aug) 최고 점수: 12.22%
# A0 (Squash) 방식 추천 (증강이 성능을 떨어뜨림)

# %% [markdown]
# # B0, B1 Optimizer 변경 (Adam vs AdamW) - 채정

# %%
## 1. B0 / B1 옵티마이저 설정에 따라 학습을 수행하는 함수 정의
def train_with_optimizer_config(train_ds, val_ds, epochs=10, mode_name="B1_AdamW"):
    # 2. 모델 생성 (아까 통합한 build_model_head 호출!)
    # 주의: 여기서 build_model_with_optimizer 대신 build_model_head를 씁니다.
    model = build_model_head(
        head_units=256,
        dropout_rate=0.5,
        lr=0.001,
        optimizer_name="adamw"
    )

    # 콜백 기본 세팅 (EarlyStopping + ModelCheckpoint + CSVLogger)
    os.makedirs("runs", exist_ok=True)

    ckpt_path = f"runs/best_head_{mode_name}.keras"
    log_path = f"runs/train_log_{mode_name}.csv"

    cb_list = [
        callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
        callbacks.ModelCheckpoint(ckpt_path, monitor='val_accuracy', mode='max', save_best_only=True),
        callbacks.CSVLogger(log_path)
    ]

    # [핵심] ReduceLROnPlateau 스케줄러 추가 (무조건 적용)
    lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-5, verbose=1)
    cb_list.append(lr_scheduler)

    print(f"=== [{mode_name}] 학습 시작 (Optimizer: AdamW) ===")

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=cb_list,
        verbose=1
    )

    best_val = max(history.history["val_accuracy"])
    print(f"최고 정확도: {best_val:.4f}")

    return model, history, best_val

# %%
### 옵티마이저 설정에 따른 단독 실험 불필요 → 이후 내용 전부 주석 처리
exp_opt_histories = {}  # 그래프 그릴 데이터를 모을 딕셔너리
exp_opt_results = {}    # 최고 점수를 모을 딕셔너리

# [B0 기준 모델] A0의 결과를 그대로 사용
history_B0 = history_A0
acc_B0 = max(history_B0.history["val_accuracy"])

exp_opt_histories["B0"] = history_B0.history
exp_opt_results["B0"] = acc_B0

# [B1 실험] AdamW + Scheduler
model_B1, history_B1, acc_B1 = train_with_optimizer_config(train_ds=train_ds_A0,
                                                           val_ds = val_ds_A0,
                                                           mode_name ="B1_AdamW")
exp_opt_histories["B1_AdamW"] = history_B1.history
exp_opt_results["B1_AdamW"] = acc_B1

print("최종 모델 (B0: Adam / B1: AdamW + Scheduler) 2개 학습 완료!")
# Out:
# === [B1_AdamW] 학습 시작 (Optimizer: AdamW) ===
# Epoch 1/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 729ms/step - accuracy: 0.2088 - loss: 2.3064 - val_accuracy: 0.3489 - val_loss: 1.8492 - learning_rate: 0.0010
# Epoch 2/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 84s 746ms/step - accuracy: 0.3322 - loss: 1.8163 - val_accuracy: 0.3911 - val_loss: 1.7678 - learning_rate: 0.0010
# Epoch 3/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 85s 750ms/step - accuracy: 0.3599 - loss: 1.7406 - val_accuracy: 0.4044 - val_loss: 1.6835 - learning_rate: 0.0010
# Epoch 4/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 79s 700ms/step - accuracy: 0.4030 - loss: 1.6641 - val_accuracy: 0.4044 - val_loss: 1.6676 - learning_rate: 0.0010
# Epoch 5/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 88s 749ms/step - accuracy: 0.4187 - loss: 1.6220 - val_accuracy: 0.4133 - val_loss: 1.6821 - learning_rate: 0.0010
# Epoch 6/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 84s 746ms/step - accuracy: 0.4314 - loss: 1.5682 - val_accuracy: 0.4156 - val_loss: 1.6253 - learning_rate: 0.0010
# Epoch 7/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 79s 699ms/step - accuracy: 0.4401 - loss: 1.5560 - val_accuracy: 0.4433 - val_loss: 1.6065 - learning_rate: 0.0010
# Epoch 8/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 86s 738ms/step - accuracy: 0.4485 - loss: 1.5063 - val_accuracy: 0.4356 - val_loss: 1.6118 - learning_rate: 0.0010
# Epoch 9/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.4573 - loss: 1.4898
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 147s 779ms/step - accuracy: 0.4572 - loss: 1.4899 - val_accuracy: 0.4367 - val_loss: 1.6165 - learning_rate: 0.0010
# Epoch 10/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 134s 705ms/step - accuracy: 0.4799 - loss: 1.4265 - val_accuracy: 0.4556 - val_loss: 1.5545 - learning_rate: 5.0000e-04
# 최고 정확도: 0.4556
# 최종 모델 (B0: Adam / B1: AdamW + Scheduler) 2개 학습 완료!

# %%
from matplotlib.ticker import MaxNLocator

def plot_optimizer_experiments(histories_dict):
    plt.figure(figsize=(12, 5))

    # 1) Validation Accuracy 비교
    plt.subplot(1, 2, 1)
    for config_name, hist in histories_dict.items():
        epochs = range(1, len(hist["val_accuracy"]) + 1)
        plt.plot(epochs, hist["val_accuracy"], marker='o', label=f"val_acc")

    plt.title("B0 vs B1 - Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True)) # X축 정수만 표시

    # 2) Training Accuracy 비교
    plt.subplot(1, 2, 2)
    for config_name, hist in histories_dict.items():
        epochs = range(1, len(hist["accuracy"]) + 1)
        plt.plot(epochs, hist["accuracy"], marker='o', linestyle='--', label=f"train_acc")

    plt.title("B0 vs B1 - Training Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True)) # X축 정수만 표시

    plt.tight_layout()
    plt.show()

# 4. 그래프 및 결론 출력
plot_optimizer_experiments(exp_opt_histories)

print(f"\n[최종 결과 비교]")
print(f" - B0 (Adam) 최고 점수: {exp_opt_results['B0']:.4f}")
print(f" - B1 (AdamW + Sch) 최고 점수: {exp_opt_results['B1_AdamW']:.4f}")

if exp_opt_results['B1_AdamW'] > exp_opt_results['B0']:
    print("B1 (AdamW + Scheduler) 방식이 더 우수합니다.")
else:
    print("B0 (Adam) 방식이 더 우수하거나 비슷합니다.")
# Out:
# [최종 결과 비교]
#  - B0 (Adam) 최고 점수: 0.4344
#  - B1 (AdamW + Sch) 최고 점수: 0.4556
# B1 (AdamW + Scheduler) 방식이 더 우수합니다.

# %% [markdown]
# # C0, C1 파인튜닝 성능 개선 - 채민

# %%
print("--- C1 파인튜닝 실험 시작 ---")

def run_fine_tuning(base_model_path, train_ds, val_ds,
                    mode_name="C1_FineTuned",
                    unfreeze_count=3,
                    base_lr=1e-5,
                    initial_epoch=10,
                    add_epochs=10):
    """
    base_model_path: C0(A0) 모델이 저장된 경로 (예: runs/best_head_A0_Squash_Final.keras)
    train_ds, val_ds: 데이터셋
    mode_name: 저장될 파일 이름 태그
    unfreeze_count: 뒤에서부터 몇 개의 레이어를 풀 것인지 (기본 10)
    base_lr: 파인튜닝 학습률 (아주 낮게 설정, 기본 1e-5)
    initial_epoch: C0가 끝난 시점 (그래프 이어그리기용, 기본 20)
    add_epochs: 추가로 더 학습할 횟수 (기본 10)
    """
    print(f"[C1 파인튜닝 시작] 모드: {mode_name}")
    print(f"로드 경로: {base_model_path}")

    # 1. C0 모델 로드
    if not os.path.exists(base_model_path):
        raise FileNotFoundError(f"모델 파일을 찾을 수 없습니다: {base_model_path}")

    model = models.load_model(base_model_path)

    # 2. 베이스 모델(MobileNetV2) 찾기 및 동결 해제
    # Sequential 모델의 경우 layers[0]이 보통 백본입니다.
    # 안전을 위해 이름에 'mobilenet'이 들어간 레이어를 찾습니다.
    base_model = None
    # for layer in model.layers:
    #     if "mobilenet" in layer.name.lower():
    #         base_model = layer
    #         break

    # if base_model is None:
    #     # 못 찾으면 그냥 첫 번째 레이어를 백본으로 간주 (Sequential의 경우)
    #     base_model = model.layers[0]
    #     print("주의: 이름으로 백본을 못 찾아 첫 번째 레이어를 선택했습니다.")

    # 2. 베이스 모델(MobileNetV2) 접근
    # model_C1.layers[1]이 MobileNetV2 백본임을 직접 지정하여 안정성 확보
    base_model = model.layers[1]

    # 전체 동결 해제 후 -> 앞부분 다시 동결
    base_model.trainable = True

    # 전체 레이어 수 - 10개 지점 계산
    fine_tune_at = len(base_model.layers) - unfreeze_count

    # 앞부분 다시 얼리기
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    print(f"--> 전체 레이어 {len(base_model.layers)}개 중 뒤쪽 {unfreeze_count}개만 학습합니다.")

    # 3. 컴파일 (낮은 학습률 필수!)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=base_lr),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # 4. 콜백 설정
    os.makedirs("runs", exist_ok=True)
    ckpt_path = f"runs/best_model_{mode_name}.keras"
    log_path = f"runs/train_log_{mode_name}.csv"

    cbs_C1 = [
        callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
        callbacks.ModelCheckpoint(ckpt_path, monitor='val_accuracy', mode='max', save_best_only=True),
        callbacks.CSVLogger(log_path)
    ]

    # 5. 학습 시작
    # repeat() 없이 dataset 그대로 사용 (tf.data 파이프라인이 잘 되어 있다면 이게 정석)
    total_epochs = initial_epoch + add_epochs

    history_C1 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=total_epochs,
        initial_epoch=initial_epoch, # 20부터 시작한다고 명시 (그래프 X축 연결됨)
        callbacks=cbs_C1,
        verbose=1
    )

    print(f"--- [{mode_name}] 파인튜닝 완료! 저장경로: {ckpt_path} ---")
    return model, history_C1
# Out:
# --- C1 파인튜닝 실험 시작 ---

# %%
# 1. 불러올 C0 모델 경로 지정
load_path = "runs/best_head_A0_Squash.keras"

# 2. C1 파인튜닝 실행
# train_ds_A0와 val_ds_A0를 그대로 사용합니다.
model_C1, history_C1 = run_fine_tuning(
    base_model_path=load_path,
    train_ds=train_ds_A0,
    val_ds=val_ds_A0,
    mode_name="C1_FineTuned_Squash",  # 파일명 태그
    unfreeze_count=3,                 # 3개만 풀기
    base_lr=5e-5,                     # 학습률 0.00005
    initial_epoch=10,                 # 10 epoch부터 시작
    add_epochs=15                     # 10 epoch 추가 (총 20까지)
)
# Out:
# [C1 파인튜닝 시작] 모드: C1_FineTuned_Squash
# 로드 경로: runs/best_head_A0_Squash.keras
# --> 전체 레이어 154개 중 뒤쪽 3개만 학습합니다.
# Epoch 11/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 716ms/step - accuracy: 0.3292 - loss: 3.2196 - val_accuracy: 0.2633 - val_loss: 2.4106
# Epoch 12/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 79s 699ms/step - accuracy: 0.4369 - loss: 1.7394 - val_accuracy: 0.2144 - val_loss: 2.5125
# Epoch 13/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 87s 744ms/step - accuracy: 0.4884 - loss: 1.4524 - val_accuracy: 0.2267 - val_loss: 2.3319
# Epoch 14/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 84s 745ms/step - accuracy: 0.5431 - loss: 1.3237 - val_accuracy: 0.2500 - val_loss: 2.1926
# Epoch 15/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 85s 750ms/step - accuracy: 0.5531 - loss: 1.2537 - val_accuracy: 0.2667 - val_loss: 2.1241
# Epoch 16/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 80s 708ms/step - accuracy: 0.5788 - loss: 1.1638 - val_accuracy: 0.2878 - val_loss: 2.0400
# Epoch 17/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 81s 715ms/step - accuracy: 0.6014 - loss: 1.1212 - val_accuracy: 0.3100 - val_loss: 1.9522
# Epoch 18/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 80s 702ms/step - accuracy: 0.6118 - loss: 1.0718 - val_accuracy: 0.3500 - val_loss: 1.8364
# Epoch 19/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 79s 699ms/step - accuracy: 0.6431 - loss: 1.0261 - val_accuracy: 0.3644 - val_loss: 1.7855
# Epoch 20/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 703ms/step - accuracy: 0.6677 - loss: 0.9645 - val_accuracy: 0.4033 - val_loss: 1.6929
# Epoch 21/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 79s 697ms/step - accuracy: 0.6740 - loss: 0.9431 - val_accuracy: 0.4078 - val_loss: 1.6721
# Epoch 22/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 698ms/step - accuracy: 0.6921 - loss: 0.9207 - val_accuracy: 0.4222 - val_loss: 1.6354
# Epoch 23/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 79s 700ms/step - accuracy: 0.7073 - loss: 0.8633 - val_accuracy: 0.4344 - val_loss: 1.6174
# Epoch 24/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 80s 703ms/step - accuracy: 0.7278 - loss: 0.8283 - val_accuracy: 0.4611 - val_loss: 1.5944
# Epoch 25/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 78s 692ms/step - accuracy: 0.7330 - loss: 0.7907 - val_accuracy: 0.4589 - val_loss: 1.6118
# --- [C1_FineTuned_Squash] 파인튜닝 완료! 저장경로: runs/best_model_C1_FineTuned_Squash.keras ---

# %%
# C0의 최고 val_accuracy
c0_best_acc = max(history_A0.history['val_accuracy'])
c1_best_acc = max(history_C1.history['val_accuracy'])

print(f"C0 (동결) 최고 정확도: {c0_best_acc:.4f}")
print(f"C1 (파인튜닝 - 에포크 증가) 최고 정확도: {c1_best_acc:.4f}")

if c1_best_acc > c0_best_acc:
    print(f"--> 성능 개선 확인: {c1_best_acc - c0_best_acc:.4f} 만큼 향상됨!")
else:
    print("--> 성능 개선 없음. (학습률, 동결 레이어 수 등 재검토 필요)")
# Out:
# C0 (동결) 최고 정확도: 0.4344
# C1 (파인튜닝 - 에포크 증가) 최고 정확도: 0.4611
# --> 성능 개선 확인: 0.0267 만큼 향상됨!

# %%
def plot_compare(history_A0, history_C1):
    acc_c0 = history_A0.history['val_accuracy']
    acc_c1 = history_C1.history['val_accuracy']

    loss_c0 = history_A0.history['val_loss']
    loss_c1 = history_C1.history['val_loss']

    plt.figure(figsize=(12, 5))

    # Accuracy 비교
    plt.subplot(1, 2, 1)
    plt.plot(acc_c0, label='C0 (Frozen) Val Acc', linestyle='--')
    plt.plot(range(len(acc_c0), len(acc_c0) + len(acc_c1)), acc_c1, label='C1 (Fine-tuned) Val Acc', color='red')
    plt.title('Accuracy Comparison')
    plt.xlabel('Epochs')
    plt.legend()

    # Loss 비교
    plt.subplot(1, 2, 2)
    plt.plot(loss_c0, label='C0 (Frozen) Val Loss', linestyle='--')
    plt.plot(range(len(loss_c0), len(loss_c0) + len(loss_c1)), loss_c1, label='C1 (Fine-tuned) Val Loss', color='red')
    plt.title('Loss Comparison')
    plt.xlabel('Epochs')
    plt.legend()

    plt.show()

plot_compare(history_A0, history_C1)
